# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('healthcare_test.csv')

# %%
df.head()
# Out:
#                                       documents/name  \
# 0  projects/healthcare-test01/databases/(default)...
# 1  projects/healthcare-test01/databases/(default)...
# 2  projects/healthcare-test01/databases/(default)...
# 3  projects/healthcare-test01/databases/(default)...
# 4  projects/healthcare-test01/databases/(default)...
#
#    documents/fields/idNumber/stringValue documents/fields/surname/stringValue  \
# 0                          1269900350207                               พรหมณี
# 1                          3100700640618                                กังวล
# 2                          3102201532596                             ศรีระยับ
# 3                          3150300024529                             ไม้เนียม
# 4                          3250500511902                               จะละสุ
#
#    documents/fields/healthData/mapValue/fields/bloodPressureSystolic/integerValue  \
# 0                                                105
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 25 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   documents/name                                                                   27 non-null     object
#  1   documents/fields/idNumber/stringValue                                            27 non-null     int64
#  2   documents/fields/surname/stringValue                                             27 non-null     object
#  3   documents/fields/healthData/mapValue/fields/bloodPressureSystolic/integerValue   27 non-null     int64
#  4   documents/fields/healthData/mapValue/fields/weight/doubleValue                   3 non-null      float64
#  5   documents/fields/healthData/mapValue/fields/temperature/doubleValue              25 non-null     float64
# ...

# %%
df = df.drop(columns=['documents/name','documents/fields/updatedAt/timestampValue','documents/createTime','documents/updateTime','documents/fields/createdAt/timestampValue'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 20 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   documents/fields/idNumber/stringValue                                            27 non-null     int64
#  1   documents/fields/surname/stringValue                                             27 non-null     object
#  2   documents/fields/healthData/mapValue/fields/bloodPressureSystolic/integerValue   27 non-null     int64
#  3   documents/fields/healthData/mapValue/fields/weight/doubleValue                   3 non-null      float64
#  4   documents/fields/healthData/mapValue/fields/temperature/doubleValue              25 non-null     float64
#  5   documents/fields/healthData/mapValue/fields/height/doubleValue                   1 non-null      float64
# ...

# %%
df.columns= ['ID','Surname','Systolic','Weight','Temperature','Height','tookAntihypertensive','BMI','Glucose','Oxygen','Diastolic','Name','Age','Gender','']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 df.columns= ['ID','Surname','Systolic','Weight','Temperature','Height','tookAntihypertensive','BMI','Glucose','Oxygen','Diastolic','Name','Age','Gender','']
#
# File ~/Documents/study/pythonProject/.venv/lib/python3.9/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/Documents/study/pythonProject/.venv/lib/python3.9/site-packages/pandas/core/generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
# ...
