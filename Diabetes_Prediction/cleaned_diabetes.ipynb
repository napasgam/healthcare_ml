# %% [raw]
# Diabetes Test Dataset

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Dataset/healthCheckup.csv')

# %%
df.head()
# Out:
#        ID Number       Name     Surname  Age  Gender  \
# 0  1269900350207  วัชรศักย์      พรหมณี   22  Female
# 1  1650400096270      มลฤดี  สว่างพิมพ์   37  Female
# 2  2260300017663    เพ็ญพิศ     ประสงค์   60  Female
# 3  2260300018244   สุนารีย์      จันหอม   38  Female
# 4  3100700640618  รัตนาวรรณ       กังวล   60  Female
#
#                  Created At                Updated At  Height  Weight   BMI  \
# 0  2025-02-16T04:01:54.254Z  2025-02-16T04:01:54.254Z     166    67.0  24.3
# 1  2025-02-14T04:17:44.934Z  2025-02-14T04:17:44.934Z     164    57.0  21.2
# 2  2025-02-13T04:31:55.404Z  2025-02-13T04:31:55.404Z     149    70.0  31.5
# 3  2025-02-14T05:37:41.537Z  2025-02-14T05:37:41.537Z     157    60.0  24.3
# 4  2025-01-24T08:48:13.164Z  2025-01-24T08:48:13.164Z     160    74.5  29.1
#
#    ...  Blood Pressure Diastolic  Temperature  Took Antihypertensive  \
# 0  ...                        63         37.9                  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID Number                 49 non-null     int64
#  1   Name                      49 non-null     object
#  2   Surname                   49 non-null     object
#  3   Age                       49 non-null     int64
#  4   Gender                    49 non-null     object
#  5   Created At                49 non-null     object
#  6   Updated At                49 non-null     object
#  7   Height                    49 non-null     int64
#  8   Weight                    49 non-null     float64
#  9   BMI                       48 non-null     float64
#  10  Blood Sugar               49 non-null     int64
#  11  Blood Oxygen              49 non-null     int64
#  12  Blood Pressure Systolic   49 non-null     int64
#  13  Blood Pressure Diastolic  49 non-null     int64
# ...

# %%
df.drop(columns=['ID Number','Name','Surname','Gender','Weight','Height','Created At','Updated At','House Number','Road','Lane','Village Number','Sub District','District','Province','Blood Oxygen','Blood Pressure Systolic','Temperature','Took Antihypertensive'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       49 non-null     int64
#  1   BMI                       48 non-null     float64
#  2   Blood Sugar               49 non-null     int64
#  3   Blood Pressure Diastolic  49 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 1.7 KB

# %%
df.rename(columns={'Blood Sugar': 'Glucose', 'Blood Pressure Diastolic': 'BloodPressure'}, inplace=True)

# %%
df
# Out:
#     Age   BMI  Glucose  BloodPressure
# 0    22  24.3       77             63
# 1    37  21.2       95             60
# 2    60  31.5       96             79
# 3    38  24.3      110             79
# 4    60  29.1      100             71
# 5    65  29.6      145             80
# 6    68  25.6       93             72
# 7    62  21.9      108             78
# 8    72  22.2       94             61
# 9    56  24.6      115             74
# 10   64  19.2      125             87
# 11   71  20.6       93             55
# 12   43  29.4       92             76
# 13   68  29.5       96             74
# 14   83  20.5       92             60
# 15   65  23.8       94             52
# 16   66  33.3       98             76
# 17   57  28.6      393             90
# 18   59  22.5       95             58
# 19   59  26.2      140             73
# 20   62  26.2      181             77
# 21   62  24.4       94             91
# 22   62  21.2       96             70
# 23    0  27.1      222             85
# ...

# %%
new_order = ['Glucose','BloodPressure','BMI','Age']

# %%
df = df[new_order]

# %%
df
# Out:
#     Glucose  BloodPressure   BMI  Age
# 0        77             63  24.3   22
# 1        95             60  21.2   37
# 2        96             79  31.5   60
# 3       110             79  24.3   38
# 4       100             71  29.1   60
# 5       145             80  29.6   65
# 6        93             72  25.6   68
# 7       108             78  21.9   62
# 8        94             61  22.2   72
# 9       115             74  24.6   56
# 10      125             87  19.2   64
# 11       93             55  20.6   71
# 12       92             76  29.4   43
# 13       96             74  29.5   68
# 14       92             60  20.5   83
# 15       94             52  23.8   65
# 16       98             76  33.3   66
# 17      393             90  28.6   57
# 18       95             58  22.5   59
# 19      140             73  26.2   59
# 20      181             77  26.2   62
# 21       94             91  24.4   62
# 22       96             70  21.2   62
# 23      222             85  27.1    0
# ...

# %%
df.isnull().sum()
# Out:
# Glucose          0
# BloodPressure    0
# BMI              1
# Age              0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# /var/folders/zq/6xpyjvds7tv_bz1html9bdlw0000gn/T/ipykernel_4451/658506679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 0 to 48
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Glucose        48 non-null     int64
#  1   BloodPressure  48 non-null     int64
#  2   BMI            48 non-null     float64
#  3   Age            48 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 1.9 KB

# %%
df.to_csv('healthCheckup_diabetes.csv', index=False)
